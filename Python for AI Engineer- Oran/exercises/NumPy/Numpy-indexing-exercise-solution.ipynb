# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Exercise: Indexing and Slicing
#
# Use `plt.imread(filename)` to load an image file:

# %%
a = plt.imread("pencils.jpeg")

# %%
a.shape, a.dtype
# Out:
# ((480, 640, 3), dtype('uint8'))

# %%
plt.imshow(a);

# %% [markdown]
# ## Part 0: show only this part of the image
# ![partial image](pencils-part.png)

# %%
plt.imshow(a[200:400, 250:450]);

# %% [markdown]
# ## Part 1: Show the image flipped vertically

# %%
plt.imshow(a[::-1]);

# %% [markdown]
# ## Part 2: Show the image flipped horizontally

# %%
plt.imshow(a[:,::-1]);

# %%
a
# Out:
# array([[[180,   4,   6],
#         [169,   0,   0],
#         [176,   8,   0],
#         ...,
#         [147, 153, 125],
#         [145, 151, 123],
#         [144, 150, 122]],
#
#        [[184,   0,   2],
#         [182,   4,   2],
#         [171,   2,   0],
#         ...,
#         [154, 160, 132],
#         [143, 152, 123],
#         [138, 147, 118]],
#
#        [[194,   0,   0],
#         [190,   6,   6],
#         [168,   1,   0],
#         ...,
#         [150, 159, 130],
#         [142, 151, 122],
#         [140, 151, 121]],
#
#        ...,
#
#        [[244, 238, 240],
#         [238, 232, 234],
#         [236, 227, 232],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[242, 237, 241],
#         [235, 230, 234],
#         [231, 225, 229],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[240, 238, 239],
#         [232, 230, 233],
#         [230, 225, 229],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
plt.imshow(a[:,:,::-1]);

# %% [markdown]
# ## Part 3: Show channels r,g and b

# %% [markdown]
# * (Bonus 1: Do the same, using a loop. Use `plt.show()` to show the current figure and start a new figure. Use `plt.title()` to show a title )
# * (Bonus 2: Use `imshow(..., vmin=..., vmax=...)` to disable normalization and stretch the scale.)

# %%
for i, c in enumerate(('Reds', 'Greens', 'Blues')):
    plt.imshow(a[:,:,i], c, vmin=0, vmax=255)
    plt.colorbar()
    plt.title(c)
    plt.show()

# %% [markdown]
# ## Part 4: Show the image with channels R and B swapped.

# %%
plt.imshow(a[:,:,::-1]); # RGB to BGR

# Option 2
# plt.imshow(a[:,:,[2,1,0]]);

# %% [markdown]
# Source:
# * 10x - https://lms.10x.org.il/
